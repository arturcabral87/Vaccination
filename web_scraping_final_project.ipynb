# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.who.int/countries"

response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
type(response)

#content
print(response.content)
# Out:
# b' <!DOCTYPE html> <html lang="en"> <head>  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" /> <meta charset="utf-8" /><meta name="viewport" content="width=device-width, initial-scale=1"><title>\r\n\tCountries | World Health Organization\r\n</title> <link rel="shortcut icon" href="/favicon.ico"> <link rel="manifest" href="/manifest.json"> <link rel="apple-touch-icon" href="/apple-touch-icon-precomposed.png"> <meta name="theme-color" content="#007eb4" /> <link rel="preconnect" href="https://fonts.googleapis.com" /> <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin /> <link rel="preconnect" href="https://use.fontawesome.com" crossorigin /> <link rel="dns-prefetch" href="https://cdnjs.cloudflare.com" /> <link rel="dns-prefetch" href="https://kendo.cdn.telerik.com" /> <link rel="prefetch" href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js"> <link rel="prefetch" href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js"> <link rel="preconnect" href="https://cdn.who.int" /> <link href="https://fonts.googleapis.com/css2?family=Noto+Sans:ital,wght@0,400;0,700;1,400&display=swap" rel="stylesheet"> <link href="https://use.fontawesome.com/releases/v5.15.4/css/all.css" rel="stylesheet" type="text/css" /> <link rel="stylesheet" href="/ResourcePackages/WHO/assets/dist/styles/grid.min.css?v=14.0.7729.18857">  <link rel="stylesheet" href="/ResourcePackages/WHO/assets/dist/styles/origin.min.css?v=14.0.7729.18857"><link rel="stylesheet" href="/ResourcePackages/WHO/assets/dist/styles/main.min.css?v=14.0.7729.18857"> <link rel="stylesheet" href="/ResourcePackages/WHO/assets/dist/styles/print.min.css?v=14.0.7729.18857" media="print">\n<script>\r\n                var lang = document.documentElement.lang; \r\n                window.dataLayer = window.dataLayer || []; \r\n                window.dataLayer.push({\'language\': lang });\r\n                window.dataLayer.push({\r\n  "pagetype": "collectionpage",\r\n  "targetaudience": "general-audience",\r\n  "targetcountry": "global",\r\n  "publishingoffice": "who-worldwide",\r\n  "healthtopic": "None"\r\n});</script> <script>\r\n                    (function() {\r\n                    function deleteCookie(cookieName,domain) {\r\n                        document.cookie = cookieName + \'=;expires=Mon Jan 01 1900 00:00:00 ; path=/; domain=\' + domain;\r\n                    }\r\n                    function loadAndTrack(canTrack) {\r\n                        if (!canTrack) {\r\n                            var domain = location.hostname.replace(/^www\\./i, \'.\');\r\n                            //GA\r\n                            deleteCookie(\'_ga\', domain);\r\n                            deleteCookie(\'_gat\', domain);\r\n                            deleteCookie(\'_gid\', domain);\r\n                            //Clarity\r\n                            deleteCookie(\'_clck\', domain);\r\n                            deleteCookie(\'_clsk\', domain);\r\n                            //Google Adsense\r\n                            deleteCookie(\'_gcl_au\', domain);\r\n                        }\r\n                        else{\r\n                            //Fire GTM\r\n                            //Google Tag Manager\r\n                                (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\n                                new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\n                                j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n                                \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n                                })(window,document,\'script\',\'dataLayer\',\'GTM-5QFSQRT\');\r\n                            //End Google Tag Manager\r\n                        }\r\n                        return;\r\n                    }\r\n\r\n                    if (window.TrackingConsentManager)  ...

# %%
soup = BeautifulSoup(response.content)
soup
# Out:
#  <!DOCTYPE html>
#  <html lang="en"> <head> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title>
# 	Countries | World Health Organization
# </title> <link href="/favicon.ico" rel="shortcut icon"/> <link href="/manifest.json" rel="manifest"/> <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/> <meta content="#007eb4" name="theme-color"> <link href="https://fonts.googleapis.com" rel="preconnect"> <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"> <link crossorigin="" href="https://use.fontawesome.com" rel="preconnect"> <link href="https://cdnjs.cloudflare.com" rel="dns-prefetch"/> <link href="https://kendo.cdn.telerik.com" rel="dns-prefetch"/> <link href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js" rel="prefetch"/> <link href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js" rel="prefetch"/> <link href="https://cdn.who.int" rel="preconnect"> <link href="https://fonts.googleapis.com/css2?family=Noto+Sans:ital,wght@0,400;0,700;1,400&amp;display=swap" rel="stylesheet"/> <link href="https://use.fontawesome.com/releases/v5.15.4/css/all.css" rel="stylesheet" type="text/css"> <link href="/ResourcePackages/WHO/assets/dist/styles/grid.min.css?v=14.0.7729.18857" rel="stylesheet"/> <link href="/ResourcePackages/WHO/assets/dist/styles/origin.min.css?v=14.0.7729.18857" rel="stylesheet"/><link href="/ResourcePackages/WHO/assets/dist/styles/main.min.css?v=14.0.7729.18857" rel="stylesheet"/> <link href="/ResourcePackages/WHO/assets/dist/styles/print.min.css?v=14.0.7729.18857" media="print" rel="stylesheet"/>
# <script>
#                 var lang = document.documentElement.lang;
#                 window.dataLayer = window.dataLayer || [];
#                 window.dataLayer.push({'language': lang });
#                 window.dataLayer.push({
#   "pagetype": "collectionpage",
#   "targetaudience": "general-audience",
#   "targetcountry": "global",
#   "publishingoffice": "who-worldwide",
#   "healthtopic": "None"
# });</script> <script>
#                     (function() {
#                     function deleteCookie(cookieName,domain) {
#                         document.cookie = cookieName + '=;expires=Mon Jan 01 1900 00:00:00 ; path=/; domain=' + domain;
#                     }
#                     function loadAndTrack(canTrack) {
#                         if (!canTrack) {
#                             var domain = location.hostname.replace(/^www\./i, '.');
#                             //GA
#                             deleteCookie('_ga', domain);
#                             deleteCookie('_gat', domain);
#                             deleteCookie('_gid', domain);
#                             //Clarity
#                             deleteCookie('_clck', domain);
#                             deleteCookie('_clsk', domain);
#                             //Google Adsense
#                             deleteCookie('_gcl_au', domain);
#                         }
#                         else{
#                             //Fire GTM
#                             //Google Tag Manager
#                                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                                 })(window,document,'script','dataLayer','GTM-5QFSQRT');
#                             //End Google Tag Manager
#                         }
#                         return;
#                     }
#
#                     if (window.TrackingConsentManager) {
#                         TrackingConsentManager.addEventListener('ConsentChanged', loadAndTrack);
#                         loadAndTrack(TrackingConsentManager.canTrackCurrentUser());
#                     }
#                     else {
#                         loadAndTrack(true);
#                     }
#                     })();
#                 </script><meta content="en_US" property="og:locale"/><meta content="Countries overview | World Health Organization" property="og:title"/><meta content="Countries overview" property="og:description"/><style media="all" type="text/css">    figure.sf-publications-item__figure {margin:0 !important;width:100% !important;height:210px !important;flex-grow: 1;flex-shrink: 1;flex-direction: column;}
# .sf-publications-list .sf-publications-item__figure img {width:100%;height:auto;display: flex;flex-grow: 1;flex-shrink: 1;flex-direction: column;}
# .sf-publications-item__body {display:flex !important;flex-direction:column;flex-grow:1;flex-shrink:1;}
# .sf-publications-list .sf-publications-item__date span {display:flex !important;flex-direction:column;flex-grow:1;flex-shrink:1;height: 100%;margin-top: 1em;}
# .sf-publications-item__container {display:flex !important;flex-direction:column !important;height:100%;flex-grow:1;margin-bottom:2em !important;}
# .sf-publications-list .sf-publications-item__header {display:flex !important;flex-direction:column !important; flex-grow:1;flex-shrink:1; height:100%;}
# figure.sf-publications-item__figure { margin: 0 !important; width: 100% !important; height: auto !important; flex-grow: 1; flex-shrink: 1; flex-direction: column;}
#
# @media only screen and (max-width: 420px) {
#     .sf-publications-list .sf-publications-item__figure {display:none;}
#     .col-sm-4.col-md-3
#     {
#         width: 100% !important;
#     }
# }
# @media only screen and (min-width:420px) and (max-width: 792px) {
#     .sf-publications-list .sf-publications-item__figure {display:none;}
#     .col-sm-4.col-md-3
#     {
#         width: 50% !important;
#     }
# }
#
# .sf-publications-item__container {padding:0px;}
# .sf-publications-list .sf-publications-item__figure img {box-shadow: none;}
# figure.sf-publications-item__figure {flex-grow:0;}
# .sf-publications-list .sf-publications-item__body {padding:12px 12px 0px 12px;height: 100%;min-height: 100%;}
# .sf-publications-item__container:hover {box-shadow: 0px 2px 6px rgba(0, 0, 0, 0.15);}
# .sf-publications-list .sf-publications-item__date span {margin-top:0px;font-size:12px;color:#6a6a6a;}
# .sf-publications-list h3.sf-publications-item__title {height:4em;min-height:3em;flex-grow:1;}
# .sf-publications-list .sf-publications-item__actions {display:flex;flex-grow: 0;flex-shrink: 0;flex-direction:column;height: 100%;min-height: 1px;}
# .sf-publications-list .sf-publications-item__actions {position:relative;align-content: end;align-items: end;align-self: end;vertical-align: bottom;width: 100%;}
# .sf-publications-list .sf-publications-item__file, .sf-publications-list .sf-publications-item__url {display: flex; flex-direction: row; flex-grow:1; height:100%; width: 100%;}
# .sf-publications-list .sf-publications-item__container {padding-bottom:0;width:100%;}
# .sf-publications-list .sf-publications-item__container {
#     padding: 0px 0px;
# }
# .sf-publications-list .sf-publications-item .download-url, .sf-publications-list .sf-publications-item .page-url {
#     font-size: 12px;
# }
# @media (min-width: 1020px) {
#     .sf-publications-list .sf-publications-item__container {
#         min-height: 280px;
#     }
# }
#
# .sf-publications-list .sf-publications-item__date span {
# 	margin-top: 0px;
# 	font-size: 11px;
# 	color: #6a6a6a;
# }
#
# .filter-widget__wrapper .main-filter {
#     display: block !important;
# }</style><style media="all" type="text/css">input#filter-by-region {
#     padding: 18px 0 !important;
#     background-color: #fff !important;
#     border: 0 !important;
#     border-radius: 0 !important;
#     line-height: 1 !important;
#     text-indent: 16px !important;
#     color: #6a6a6a !important;
#     height: inherit;
# }</style><style media="all" type="text/css">.row-flex{display:flex;flex-direction:row}.row-flex .card{flex-grow:1}.row-flex .sf_colsIn{display:flex;flex-direction:column;flex-grow:1}.row-flex .card__content-group{display:flex;flex-direction:column;flex-grow:1}.row-flex .card__content{display:flex;flex-grow:1}.qa-details__content .sf-accordion__content p a{outline:0;color:var(--l2-neutralForegroundRest);border-bottom:1px solid var(--l2-neutralForegroundRest);text-decoration:none}.qa-details__content .sf-accordion__content p a:focus{outline:0;color:var(--l2-accentFillHover);background-color:var(--l2-neutralFillStealthHover);border-bottom:3px solid var(--l2-neutralFocus);text-decoration:none}.qa-details__content .sf-accordion__content p a:hover{outline:0;color:var(--l2-neutralForegroundRest);background-color:var(--l2-neutralFillStealthHover);border-bottom:3px solid var(--l2-neutralFocus);text-decoration:none}.mdc-card.mdc-card--background .card-media--item{background:0 0;background:linear-gradient(180deg,rgba(255,255,255,0) 0,rgba(0,0,0,.5) 25%,#000 100%)}.mdc-card.mdc-card--background a .item--title,.mdc-card.mdc-card--background a:active .item--title,.mdc-card.mdc-card--background a:focus .item--title,.mdc-card.mdc-card--background a:hover .item--title{text-decoration:none}.mdc-card a:visited .item--title,.mdc-card.mdc-card--background .item--title{color:#fff}.card--solid.bg-dark:hover{color:#fff;background-color:#20313b;border:2px solid #fff}.card--solid.bg-dark a{color:#fff;background-color:#20313b;border:2px solid #20313b}.card--solid.bg-dark a:hover{color:#20313b;background-color:#fff;border:2px solid #20313b}.card--solid.bg-dark:focus-within{color:#fff;background-color:#20313b;border:2px solid var(--l4-neutralFocus)}.mdc-card a .item--title,.mdc-card a:visited .item--title{color:var(--l4-neutralForegroundRest)}.mdc-card a:visited .item--title{color:var(--l4-neutralForegroundRest)!important}.-sf-integrated-app body,.sfPageContainer .RadDock .rdContent a.sfAddContentLnk,.zeContentMode .sfPageContainer .RadDock .rdContent,.zeLayoutMode .sfPageContainer .RadDock .rdContent,.zeSettingsMode .sfPageContainer .RadDock .rdContent,.zeThemesMode .sfPageContainer .RadDock .rdContent{font-family:Arial,Verdana,sans-serif!important}#navigationToScrape .content-block a,.alphabetical-nav--list .alphabetical-nav--list-item a,.alphabetical-nav--list a,.nav--list a{text-decoration:none!important}.sf-events-wrapper .vertical-list-item:focus,.sf-events-wrapper .vertical-list-item:focus-within{outline:2px solid var(--l4-neutralFocus)!important}.sf-events-wrapper .vertical-list-item a:focus-within,.sf-events-wrapper .vertical-list-item:focus{outline:0}.top-header li.active>a,.top-header li.open>a,.top-header li.selected>a,.top-header li:hover>a{background-color:var(--d-l4-accentFillHover)}
# .webinars-listing .sf-multimedia-item__container {
#     aspect-ratio: 16/9;
#     width: 100%;
#     height: auto !important;
#     min-height: 304px;
# }
#
# .webinar-episodes.vertical-list .vertical-list-item .thumb {
#     min-height: 131px;
#     aspect-ratio: 16/9;
#     height: auto;
#     width: 100%;
# }
#
# @media screen and (max-width:768px) {
#     .webinar-episodes.vertical-list .vertical-list-item .thumb {display:none;}
#
# }
#
# .webinar-episodes-details .sf-multimedia-item__container {
#     height: 390px;
#     aspect-ratio: 16/9;
#     height: auto;
# }
#
# .mdc-card--background a:visited .item--title {
#     color: #fff!important;
# }
# .hero-image--content.plx-bg--transparent.text-center {
#     position: relative;
#     width: 100%;
#     max-width: 100%;
# }
# .k-safari .plx-static .inner.responsive-background-image {
#     background-attachment: unset;
#     background-position: center;
#     background-repeat: no-repeat;
#     background-size: contain;
# }
# .plx-static.hero-image--wrapper.has-caption {
#         margin-bottom: 0;
# }
# @media (max-width: 768px) {
# .row--flex, .row-flex {flex-wrap:wrap;}
# .row--flex .sf_colsIn {margin-bottom:1rem;}
# }
# </style><style media="all" type="text/css">.sf-publications-list .sf-publications-item__figure img {
#     content-visibility: auto;
# }</style><style media="all" type="text/css">@media (min-width: 1020px) {
# .row.flex-ar {display: flex;flex-direction: row;align-content: stretch;}
# .row.flex-ar .sf_colsIn.col-sm-6.col-md-3{display:flex;flex-grow:1;;margin-bottom:2em;}
#     }
# .flex-ar img.mdc-card__media--4-3 {
#     aspect-ratio: 1/1;
# }</style><meta content="summary_large_image" name="twitter:card"/><meta content="Sitefinity 14.3.8028.0 DX" name="Generator"/><link href="https://www.who.int/countries" rel="canonical"><meta content="Countries overview" name="description"/><meta content="países" name="keywords"/></link></link></link></link></link></link></meta></head> <body class="sf-body"> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QFSQRT" style="display:none;visibility:hidden" width="0"></iframe></noscript><script src="/ScriptResource.axd?d=okuX3IVIBwfJlfEQK32K3l5K7YGiATb30h89J0olbNMeAyOtdYE6_Exv9Bd_ta2_XSFvjotxKLnlt9vcM6Kg3aKCXjsPLAfc02HCCEnrn0StjUGoNmpcNHr0Q7qewBsI-wQmYIVPg1mLq03jlrRY4M-hzwvjWouuBv3ehropIpydPBUR0&amp;t=ffffffff829b44f1" type="text/javascript"></script><script src="/ScriptResource.axd?d=ePnjFy9PuY6CB3GWMX-b_9dUqj_iyHKbtZiYzX__OhcBoGTfz1BCLaN4h7Fbajcqvr0jzshQTloWygrPD-ACaSqbbnMU2RjynHKyNq228hugZnvpXRMVXdY9OyDF4Ewext63iLJGrHIt24Ious-uCOclPLq5lpYk7ok9AjUyDR56hxVu0&amp;t=ffffffff829b44f1" type="text/javascript"></script><script src="/ScriptResource.axd?d=2z9h4-hKx8Yk1hygmet7pjkFguWG8Z1Fhnuod_CvCHCExwAB9TmazYiwtnNc8_PE_sQ84nrSkjqY9EALBnpl3lcKaF9OEQUFbopzQYCfhpJXDQLR-yvNY8t812iM5Aejg6fxAEzrTW8MI2owx-zl9SrMG73lcKP32vb5eFgX02xyZpHf0&amp;t=ffffffff829b44f1" type="text/javascript"></script> <div class="sf-main-site main-site main"> <header> <div class="sf-top-header top-header" id="sf-top-header"> <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container">
# <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="TopHeader_TD9F2A204012_Col00">
# </div>
# <div class="row" data-sf-element="Row"> <div class="sf_colsIn col-md-4" data-placeholder-label="Geo Navigation" data-sf-element="Geo Navigation">
# <div id="sf-geo-navigation-container">
# <nav class="sf-geo-navigation">
# <ul class="sf-primary-geo-navigation">
# <li class="active sf-no-logo">
# <a class="mobile nav-logo" href="https://www.who.int/">
# <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue.svg?sfvrsn=aaed4f35_20"/>
# </a>
# <a class="desktop" href="https://www.who.int/">Global</a>
# </li>
# <li class="has-children">
# <a href="#">Regions</a>
# <div class="sf-secondary-geo-navigation-container">
# <div class="sf-secondary-geo-navigation-wrapper">
# <div class="sf-geo-navigation-title">
# <div class="nav-header">
# <span class="nav-logo">
# <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue.svg?sfvrsn=aaed4f35_20"/>
# </span>
# <span class="nav-title">WHO Regional websites</span>
# <div class="nav-back-btn"><i class="fas fa-angle-left"></i></div>
# </div>
# </div>
# <ul class="sf-secondary-geo-navigation sf-secondary-geo-navigation-region row">
# <li class="col-md-4">
# <a href="https://www.afro.who.int/">
# <img alt="Africa" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/africa.png?sfvrsn=3204f957_18"/>
# <span>Africa</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="https://www.paho.org/hq/index.php?lang=en">
# <img alt="Americas" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/americas.png?sfvrsn=9efd6df3_18"/>
# <span>Americas</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="https://www.who.int/southeastasia">
# <img alt="South-East Asia" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/south-east-asia.png?sfvrsn=68e76dc2_16"/>
# <span>South-East Asia</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="https://www.who.int/europe/">
# <img alt="Europe" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/europe.png?sfvrsn=c7d5c5a5_18"/>
# <span>Europe</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="http://www.emro.who.int/index.html">
# <img alt="Eastern Mediterranean" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/eastern-mediterranean.png?sfvrsn=71211e18_16"/>
# <span>Eastern Mediterranean</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="https://www.who.int/westernpacific/">
# <img alt="Western Pacific" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/western-pacific.png?sfvrsn=88cbdcd5_16"/>
# <span>Western Pacific</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# </div> <div class="sf_colsIn col-md-8" data-placeholder-label="Language Selector &amp; Search" data-sf-element="Language Selector &amp; Search" role="search">
# <div class="form-inline">
# <div class="form-group sf-search-input-wrapper" role="search">
# <div class="srchaction-wrapper">
# <span class="srchaction">
# <i aria-hidden="true" class="fa fa-search fa-2x fa-loaded" id="4c82a9e8-41e4-4fb0-bd86-520c49b93e1e"></i>
# </span>
# <input aria-autocomplete="both" aria-describedby="SearchInfo-1" class="form-control" id="a5e6b2f9-6cf7-4f02-ba8d-ce433dbe7305" placeholder="Search" title="Search input" type="search" value=""/>
# </div>
# <span class="srchtoggle">
# <i aria-hidden="true" class="fa fa-search fa-2x fa-loaded"></i>
# </span>
# <span aria-hidden="true" hidden="" id="SearchInfo-1">When autocomplete results are available use up and down arrows to review and enter to select.</span>
# </div>
# <input data-sf-role="resultsUrl" type="hidden" value="/home/search-results"/>
# <input data-sf-role="indexCatalogue" type="hidden" value="genericsearchindex1"/>
# <input data-sf-role="wordsMode" type="hidden" value="AnyWord"/>
# <input data-sf-role="disableSuggestions" type="hidden" value="true"/>
# <input data-sf-role="minSuggestionLength" type="hidden" value="3"/>
# <input data-sf-role="suggestionFields" type="hidden" value="Title,Content"/>
# <input data-sf-role="language" type="hidden" value="en"/>
# <input data-sf-role="siteId" type="hidden" value="15210d59-ad60-47ff-a542-7ed76645f0c7"/>
# <input data-sf-role="suggestionsRoute" type="hidden" value="/restapi/search/suggestions"/>
# <input data-sf-role="searchTextBoxId" type="hidden" value="#a5e6b2f9-6cf7-4f02-ba8d-ce433dbe7305"/>
# <input data-sf-role="searchButtonId" type="hidden" value="#4c82a9e8-41e4-4fb0-bd86-520c49b93e1e"/>
# </div>
# <div class="dd sf-lang-selector language-selector">
# <i class="fas fa-language"></i>
# <label for="language-selector">
# Select language
# </label>
# <select id="language-selector" name="language-selector" onchange="openLink(value)">
# <option disabled="" selected="">Select language</option>
# <option class="selected" value="en">English</option>
# <option value="ar">العربية</option>
# <option value="zh">中文</option>
# <option value="fr">Français</option>
# <option value="ru">Русский</option>
# <option value="es">Español</option>
# <option value="pt">Português</option>
# </select>
# <i class="fas fa-angle-down"></i>
# </div>
# <style>
# li.slicknav_addition.sf-lang-selector{width:100%;position:relative}li.slicknav_addition.sf-lang-selector select{min-width:100%}#search-form label{visibility:hidden}.language-selector label{width:0!important;height:0;display:inline-block;overflow:hidden}
# </style>
# </div> </div> </div> </div> <div class="main-header" id="sf-main-header"> <div class="container"> <div class="row" data-sf-element="Row"> <div class="sf_colsIn col-md-12" data-placeholder-label="Logos Geo Navigation" data-sf-element="Logos">
# <div class="header-logo logos-container"> <a class="primary-logo" href="/" title="Home"> <img alt="Home" class="logo svg" src="/ResourcePackages/WHO/assets/dist/images/logos/en/h-logo-blue.svg"/> </a> </div> </div> </div> </div>
# <div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="MainHeader_TEC2026FA002_Col00">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="MainHeader_TEC2026FA002_Col01">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="MainHeader_TEC2026FA002_Col02">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="MainHeader_TEC2026FA002_Col03">
# </div>
# </div>
# </div> <div class="navigation" id="navigationToScrape" role="navigation">
# <div class="row navWrapper" data-sf-element="Row">
# <div class="nav-container">
# <ul class="nav"></ul>
# </div>
# <ul class="nav-mobile"></ul>
# <div class="sf_colsIn col-md-12" data-placeholder-label="Menu Wrapper" data-sf-element="Menu Wrapper" id="Navigation_TD9F2A204024_Col00"><div class="navItemLayout navHomeItemLayout">
# <div class="sf_colsIn col-md-12 navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204025_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/" target="_self">Home</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204025_Col01"></div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204029_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/health-topics" target="_self">Health Topics</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204029_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_T75121FDA161_Col00"><div class="sf_colsIn horizontal" data-placeholder-label="Horizontal" data-sf-element="Horizontal" id="Navigation_TD9F2A204114_Col00">
# <div class="sf-content-block content-block">
# <div><ul><li><a data-sf-ec-immutable="" data-sf-marked="" href="/health-topics/">All topics</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#A">A</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#B">B</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#C">C</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#D">D</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#E">E</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#F">F</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#G">G</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#H">H</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#I">I</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#J">J</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#K">K</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#L">L</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#M">M</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#N">N</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#O">O</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#P">P</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#Q">Q</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#R">R</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#S">S</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#T">T</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#U">U</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#V">V</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#W">W</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#X">X</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#Y">Y</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#Z">Z</a></li></ul></div>
# </div>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_T75121FDA161_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/health-topics/resources" target="_self">Resources</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/health-topics/resources/fact-sheets" target="_self">Fact sheets</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/facts-in-pictures" target="_self">Facts in pictures</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/multimedia" target="_self">Multimedia</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/publications" target="_self">Publications</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/questions-and-answers" target="_self">Questions and answers</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/tools-and-toolkits" target="_self">Tools and toolkits</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_T75121FDA161_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/health-topics/popular" target="_self">Popular</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/health-topics/popular/covid-19" target="_self">COVID-19</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/dengue" target="_self">Dengue</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/herpes" target="_self">Herpes</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/hypertension" target="_self">Hypertension</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/mental-disorders" target="_self">Mental disorders</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/top-10-causes-of-death" target="_self">Top 10 causes of death</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_T75121FDA161_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204027_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/countries" target="_self">Countries</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204027_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204039_Col00"><div class="sf_colsIn horizontal" data-placeholder-label="Horizontal" data-sf-element="Horizontal" id="Navigation_TD9F2A204043_Col00">
# <div class="sf-content-block content-block">
# <div><ul><li><a data-sf-ec-immutable="" data-sf-marked="" href="/countries/">All countries</a></li><li><a data-sf-ec-immutable="" href="/countries/#A">A</a></li><li><a data-sf-ec-immutable="" href="/countries/#B">B</a></li><li><a data-sf-ec-immutable="" href="/countries/#C">C</a></li><li><a data-sf-ec-immutable="" href="/countries/#D">D</a></li><li><a data-sf-ec-immutable="" href="/countries/#E">E</a></li><li><a data-sf-ec-immutable="" href="/countries/#F">F</a></li><li><a data-sf-ec-immutable="" href="/countries/#G">G</a></li><li><a data-sf-ec-immutable="" href="/countries/#H">H</a></li><li><a data-sf-ec-immutable="" href="/countries/#I">I</a></li><li><a data-sf-ec-immutable="" href="/countries/#J">J</a></li><li><a data-sf-ec-immutable="" href="/countries/#K ">K</a></li><li><a data-sf-ec-immutable="" href="/countries/#L ">L</a></li><li><a data-sf-ec-immutable="" href="/countries/#M ">M</a></li><li><a data-sf-ec-immutable="" href="/countries/#N ">N</a></li><li><a data-sf-ec-immutable="" href="/countries/#O ">O</a></li><li><a data-sf-ec-immutable="" href="/countries/#P ">P</a></li><li><a data-sf-ec-immutable="" href="/countries/#Q ">Q</a></li><li><a data-sf-ec-immutable="" href="/countries/#R ">R</a></li><li><a data-sf-ec-immutable="" href="/countries/#S ">S</a></li><li><a data-sf-ec-immutable="" href="/countries/#T ">T</a></li><li><a data-sf-ec-immutable="" href="/countries/#U ">U</a></li><li><a data-sf-ec-immutable="" href="/countries/#V ">V</a></li><li><a data-sf-ec-immutable="" href="/countries/#W ">W</a></li><li><a data-sf-ec-immutable="" href="/countries/#X ">X</a></li><li><a data-sf-ec-immutable="" href="/countries/#Y ">Y</a></li><li><a data-sf-ec-immutable="" href="/countries/#Z ">Z</a></li></ul></div>
# </div>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204039_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/countries/regions" target="_self">Regions</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/countries/regions/africa" target="_self">Africa</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/americas" target="_self">Americas</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/europe" target="_blank">Europe</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/eastern-mediterranean" target="_self">Eastern Mediterranean</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/south-east-asia" target="_self">South-East Asia
# </a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/western-pacific" target="_blank">Western Pacific</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204039_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/countries/who-in-countries" target="_self">WHO in countries</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/countries/who-in-countries/cooperation-strategies" target="_self">Cooperation strategies</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/who-in-countries/data-by-country" target="_self">Data by country</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204039_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204028_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/news-room" target="_self">Newsroom</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204028_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204038_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/news/all-news" target="_self">All news</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/news/all-news/releases" target="_self">News releases</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/statements" target="_self">Statements</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/campaigns" target="_self">Campaigns</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/events" target="_self">Events</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/feature-stories" target="_self">Feature stories</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/speecheshub" target="_self">Speeches</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/commentaries" target="_self">Commentaries</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/photo-library" target="_self">Photo library</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-md-6" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204038_Col01">
# <div class="sf-content-block content-block">
# <div><ul><li><a href="/news-room/headlines">Headlines</a></li></ul></div>
# </div>
# <div class="vertical-list" id="listView"></div>
# <script id="template" type="text/x-kendo-tmpl">
#     <div class="vertical-list-item">
#         <div class="info">
#             <a href="https://www.who.int/news/item#:ItemDefaultUrl #" aria-label="#: Title #" role="link">
#                 <p class="heading">#: Title #</p>
#             </a>
#             <div class="date">
#                 <span class="timestamp">#: FormatedDate #</span>
#                 <div class="sf-tags-list">
#                     <div class="sf-tags-list-item">#: NewsType #</div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </script>
# <script>
#     window.onload = function () {
#         var remoteDataSource = new kendo.data.DataSource({
#             type: "odata-v4",
#             transport: {
#                 read: "/api/news/newsitems?sf_provider=OpenAccessDataProvider&sf_culture=en&$top=3&$orderby=PublicationDateAndTime%20desc&$select=Title,ItemDefaultUrl,FormatedDate,NewsType&$filter=publishingoffices/any(s:s eq df302c0e-1f59-4efb-b276-d154122d3760)"
#             }
#         });
#         $("#listView").kendoListView({
#             dataSource: remoteDataSource,
#             pageable: true,
#             template: kendo.template($("#template").html()),
#             dataBound: function () {
#                 this.wrapper.removeClass("k-widget");
#                 this.wrapper.removeClass("k-listview");
#             }
#         });
#     };
# </script>
# </div>
# <div class="sf_colsIn col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204038_Col02">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204040_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/emergencies" target="_self">Emergencies</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204040_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204090_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/emergencies/emergencies" target="_self">Focus on</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/afghanistan" target="_self">Afghanistan</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/cholera" target="_self">Cholera </a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/greater-horn-of-africa" target="_self">Greater Horn of Africa</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/israel-and-occupied-palestinian-territory" target="_self">Israel and occupied Palestinian territory</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/sudan" target="_self">Sudan</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/ukraine-emergency" target="_self">Ukraine</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204090_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/emergencies/news" target="_self">Latest</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/emergencies/news/disease-outbreak-news" target="_self">Disease Outbreak News</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/news/situation-reports" target="_self">Situation reports</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/news/weekly-epidemiological-record" target="_self">Weekly Epidemiological Record</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204090_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies" target="_self">WHO in emergencies</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/surveillance" target="_self">Surveillance</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/operations" target="_self">Operations</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/research-development" target="_self">Research</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/funding" target="_self">Funding</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/partners" target="_self">Partners</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/health-emergency-appeal" target="_self">Health emergency appeal</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/international-health-regulations" target="_self">International Health Regulations</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/independent-oversight-and-advisory-committee" target="_self">Independent Oversight and Advisory Committee</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204090_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_T75121FDA215_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/data" target="_self">Data</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_T75121FDA215_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_T75121FDA217_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/data/data-at-who" target="_self">Data at WHO</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/data/data-at-who/classifications" target="_self">Classifications</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/data-at-who/data-collections" target="_self">Data collections</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/data-at-who/global-health-estimates" target="_self">Global Health Estimates</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/data-at-who/mortality-database" target="_self">Mortality Database</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/data-at-who/health-sdgs" target="_self">Sustainable Development Goals</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_T75121FDA217_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/data/dashboards" target="_self">Dashboards</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/data/dashboards/covid-19-dashboard" target="_self">COVID-19</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/dashboards/health-inequality-monitor" target="_self">Health Inequality Monitor</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/dashboards/triple-billiondashboard" target="_self">Triple Billion</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_T75121FDA217_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/data/highlights" target="_self">Highlights</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/data/highlights/data-collection-tools" target="_self">Data collection tools</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/highlights/gho" target="_self">Global Health Observatory</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/highlights/insights-and-visualizations" target="_self">Insights and visualizations</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/highlights/score" target="_self">SCORE</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_T75121FDA217_Col03">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/data/reports" target="_self">Reports</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/data/reports/covid-excess-deaths" target="_self">COVID excess deaths</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/reports/world-health-statistics" target="_self">World Health Statistics</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204026_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/about-us" target="_self">About WHO</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204026_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204035_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/about" target="_self">About WHO</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/about/partnerships-and-collaboration" target="_self">Partnerships</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/expert-groups" target="_self">Committees and advisory groups</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/collaborating-centres" target="_self">Collaborating centres</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/teams" target="_self">Technical teams</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/structure" target="_self">Organizational structure</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/who-we-are" target="_self">Who we are</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204035_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/our-work" target="_self">Our work</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/our-work/activities" target="_self">Activities</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/our-work/initiatives" target="_self">Initiatives</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/our-work/global-programme-of-work" target="_self">Global Programme of Work</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/our-work/who-academy" target="_self">WHO Academy</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204035_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/who-funding" target="_self">Funding</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/who-funding/investment-case" target="_self">Investment case</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/who-funding/who-foundation" target="_self">WHO Foundation</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/accountability" target="_self">Accountability</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/accountability/audit" target="_self">Audit</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/accountability/financial-statements" target="_self">Financial statements</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/accountability/budget" target="_self">Programme budget</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/accountability/results-report" target="_self">Results Report</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204035_Col03">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/governance" target="_self">Governance</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/governance/governing-bodies-website" target="_blank">Governing bodies</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/governance/wha" target="_self">World Health Assembly</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/governance/eb" target="_self">Executive Board</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/governance/member-states-portal" target="_self">Member States Portal</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> </header> <section class="sf-content content" role="main">
# <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="PageContent_TA51A0481002_Col00">
# <div>
# <ul class="sf-breadscrumb breadcrumb">
# <li><a href="/">Home</a><span>/</span></li>
# <li class="active">Countries</li>
# </ul>
# </div>
# <script type="application/ld+json">
#     {"itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.who.int","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.who.int/countries","name":"Countries"}}],"itemListOrder":"ItemListOrderAscending","@context":"http://schema.org","@type":"BreadcrumbList"}
# </script>
# </div>
# <div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-12" data-placeholder-label="Body content" data-sf-element="Column 1" id="PageContent_TA51A0481001_Col00"><div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="PageContent_C013_Col00"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-1" data-placeholder-label="Column 1" data-sf-element="Column 1" id="PageContent_C017_Col00">
# </div>
# <div class="sf_colsIn col-md-10" data-placeholder-label="Column 2" data-sf-element="Column 2" id="PageContent_C017_Col01">
# <div class="sf-content-block content-block">
# <div><h1>Countries</h1></div>
# </div>
# <div class="sf-content-block content-block">
# <div><div>All countries which are Members of the United Nations may become members of WHO by accepting its Constitution. Other countries may be admitted as members when their application has been approved by a simple majority vote of the World Health Assembly.
# ...
# <a data-sf-ec-immutable="" href="https://www.tiktok.com/@who?lang=en" target="_blank" title="Follow WHO on TikTok"><svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
# <path d="M448,209.91a210.06,210.06,0,0,1-122.77-39.25V349.38A162.55,162.55,0,1,1,185,188.31V278.2a74.62,74.62,0,1,0,52.23,71.18V0l88,0a121.18,121.18,0,0,0,1.86,22.17h0A122.18,122.18,0,0,0,381,102.39a121.43,121.43,0,0,0,67,20.14Z" fill="white"></path></svg></a></div>
# </div>
# </div> <div class="col-md-4 copyright"> <span>
# ©
# </span>
# 2024
# <div class="sf-content-block content-block">
# <div><a href="/about/policies/terms-of-use">WHO</a></div>
# </div>
# </div> </div> </div> </div> </footer> </div> <script>
#         window.__define = window.define;
#         window.__require = window.require;
#         window.define = undefined;
#         window.require = undefined;
#     </script> <script src="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js" type="text/javascript"></script><script src="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js" type="text/javascript"></script><script src="/ResourcePackages/WHO/assets/dist/scripts/responsivelylazy.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/gsap.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/ScrollTrigger.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/ScrollToPlugin.min.js" type="text/javascript"></script><script src="/ResourcePackages/WHO/assets/dist/scripts/parallax.min.js?package=WHO" type="text/javascript"></script><script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Search/Mvc/Scripts/SearchBox/Search-box.min.js?package=WHO&amp;v=LTE4MDg1ODAzMzc%3d" type="text/javascript"></script><script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Navigation/Mvc/Scripts/LanguageSelector/language-selector.min.js?package=WHO&amp;v=MTQuMy44MDI4LjA%3d" type="text/javascript"></script><script src="/Mvc/Scripts/ContentBlock/content-block.min.js?package=WHO" type="text/javascript"></script><script id="PersonalizationTracker" type="application/json">
# 	{"IsPagePersonalizationTarget":false,"IsUrlPersonalizationTarget":false,"PageId":"9c9cb2b7-3f12-46ad-aa7e-4bc00ed9e527"}
# </script><script src="/WebResource.axd?d=Oiw5o8i74rDb2VpVaCaMStPoJ1dBeSniQ1UcN-tajp7S6UQI4QFVCojlg1ewuf339ZIyq0NtnQlSiEw1RQXcWIVwl_-LxzVLlNCkT-5fM3qvVhZCKMRq6X6cWc42Aw4Db6sa87yi7j5Hio4wozQZMklgyIbXX4yGQn_Sh0nCPeRw8nypcGpUIdT0MqtRIOGgRLfw327mU3tc3-bA3UOOd_v176Q1&amp;t=638309030020000000" type="text/javascript">
# </script><input data-sf-role="en" type="hidden" value="https://www.who.int/countries"/><input data-sf-role="ar" type="hidden" value="https://www.who.int/ar/countries"/><input data-sf-role="zh" type="hidden" value="https://www.who.int/zh/countries"/><input data-sf-role="fr" type="hidden" value="https://www.who.int/fr/countries"/><input data-sf-role="ru" type="hidden" value="https://www.who.int/ru/countries"/><input data-sf-role="es" type="hidden" value="https://www.who.int/es/countries"/><input data-sf-role="pt" type="hidden" value="https://www.who.int/pt/countries"/><script src="https://npmcdn.com/isotope-layout@3.0.6/dist/isotope.pkgd.js" type="text/javascript"></script><script type="text/javascript">
# //Localisation ISO code for Kendo Culture
# var date_localisation_format = [
#     "en-GB",
#     "ar",
#     "es-ES",
#     "fr-FR",
#     "ru-RU",
#     "zh"
# ];
#
# var textPosition = "k-ltr";
# var numberPosition = "";
# // used in isotope - set to false for arabic language
# var originLeft = true;
#
# // returns the value of the lang attribute - e.g. "en", "fr"
# var htmlLang = $("html").attr("lang");
#
# // optimized with if(htmlLang == "ar") { ... }
# //var cultureIndex = cultureIndexes[htmlLang];
#
# // defines the index of the language - 0 is EN and fallback
# var cultureIndex = 0;
#
# if(htmlLang == "ar")
# {
#     cultureIndex = 1;
#     textPosition = "k-rtl";
#     numberPosition = "number-ltr";
#     originLeft = false;
# }
# if(htmlLang == "es")
# {
#     cultureIndex = 2;
# }
# if(htmlLang == "fr")
# {
#     cultureIndex = 3;
# }
# if(htmlLang == "ru")
# {
#     cultureIndex = 4;
# }
# if(htmlLang == "zh")
# {
#     cultureIndex = 5;
# }
# if(htmlLang == "pt")
# {
#     cultureIndex = 6;
# }
#
# // filter by keyword placeholder label
# var filter_by_region = [
#     "Filter by region",
#     "تصفية حسب المنطقة",
#     "Filtrar por región de la OMS",
#     "Filtrer par région de l’OMS",
#     "Фильтр по регионам ВОЗ",
#     "按区域筛选",
#     "Filtrar por região"
# ];
#
# // filter by keyword placeholder label
# var filter_by_country = [
#     "Type to filter on a country",
#     "اكتب للتصفية علي بلد",
#     "Tipo para filtrar en un país",
#     "Type à filtrer sur un pays",
#     "Фильтр по странам",
#     "按国家筛选",
#     "Digite para filtrar por país"
# ];
#
# // link to the country overview page label
# var country_overview_page_link = [
#     "Visit the country overview",
#     "زيارة النظرة العامة القطرية",
#     "Visita la descripción del país",
#     "Consulter le survol du pays",
#     "Посетить обзор стран",
#     "访问国家概况",
#     "Visite a visão geral do país"
# ];
#
# var african_region = [
#     "African Region",
#     "المنطقة الأفريقية",
#     "Región Africana",
#     "Région africaine",
#     "Африканский регион",
#     "非洲地区",
#     "Região Africana"
# ];
#
# var eastern_mediterranean_region = [
#     "Eastern Mediterranean Region",
#     "منطقة شرق البحر الأبيض المتوسط",
#     "Región del Mediterráneo Oriental",
#     "Région de la Méditerranée orientale",
#     "Регион Восточного Средиземноморья",
#     "东地中海区域",
#     "Região do Mediterrâneo Oriental"
# ];
#
# var european_region = [
#     "European Region",
#     "المنطقة الأوروبية",
#     "Región Europea",
#     "Région européenne",
#     "Европейский регион",
#     "欧洲地区",
#     "Região Europeia"
# ];
#
# var region_of_the_americas = [
#     "Region of the Americas",
#     "منطقة الأمريكتين",
#     "Región de las Américas",
#     "Région des Amériques",
#     "Регион Америки",
#     "美洲地区",
#     "Região das Américas"
# ];
#
# var south_east_asia_region = [
#     "South-East Asia Region",
#     "منطقة جنوب شرق آسيا",
#     "Región de Asia Sudoriental",
#     "Région Asie du Sud-Est",
#     "Регион юго-восточной Азии",
#     "东南亚区域",
#     "Sudeste Asiático"
# ];
#
# var western_pacific_region = [
#     "Western Pacific Region",
#     "منطقة غرب المحيط الهادئ",
#     "Región del Pacífico Occidental",
#     "Région du Pacifique occidental",
#     "Западно-Тихоокеанский регион",
#     "西太平洋地区",
#     "Região do Pacífico Ocidental"
# ];
#
# var who_worldwide = [
#     "WHO Worldwide",
#     "منظمة الصحة العالمية في جميع أنحاء العالم",
#     "OMS en todo el mundo",
#     "OMS dans le monde",
#     "ВОЗ во всем мире",
#     "世卫组织全球",
#     "OMS em todo o mundo"
# ];
# </script><script type="text/javascript">
# var hostName = window.location.host;
# var countriesCount = 0;
# var countries = [];
# var countriesPageUrl = "/countries/";
# var position = 1;
# var buttonFilters = {};
# var buttonFilter;
# var webitCulture = "/";
# var trailingSlash = "/";
# //used to filter all countries which are member states only
# var memberStateClassificationId = "efb425be-c0b9-42d1-84b4-c3814fb5c18d";
#
# var whoRegions = [
#   { text: african_region[cultureIndex], value: ".african-region" },
#   { text: eastern_mediterranean_region[cultureIndex], value: ".eastern-mediterranean-region" },
#   { text: european_region[cultureIndex], value: ".european-region" },
#   { text: region_of_the_americas[cultureIndex], value: ".region-of-the-americas" },
#   { text: south_east_asia_region[cultureIndex], value: ".south-east-asia-region" },
#   { text: western_pacific_region[cultureIndex], value: ".western-pacific-region" },
#   { text: who_worldwide[cultureIndex], value: ".element-item" }
# ];
#
# var flagLibraryUrl = "https://" + hostName + "/images/default-source/countries-overview/flags/";
# var thumbnailProfile = ".tmb-768v";
#
# // service urls - no filtering
# var countriesBaseUrl = "https://" + hostName + "/api/multimedias/countries?$select=Title,whostatus,IsMemberstate,OfficialName,WhoCode,Code&$expand=WHORegion,Flag($select=Title,UrlName,Url,ThumbnailUrl,Extension)&$filter=whostatus/any(x:x%20eq%20" + memberStateClassificationId + ")&$orderBy=Title%20asc&sf_culture=" + htmlLang;
#
# function getAllCountriesByFilter(countriesBaseUrl) {
#   countries = [];
#   countriesCount = 0;
#
#   var countries1 = countriesBaseUrl + "&$top=100&$skip=0&$count=true";
#   var countries2 = countriesBaseUrl + "&$top=100&$skip=100&$count=true";
#   var countries3 = countriesBaseUrl + "&$top=100&$skip=200&$count=true";
#
#   $.when($.ajax(countries1), $.ajax(countries2), $.ajax(countries3))
#   .then(function(c1, c2, c3) {
#
#     // push countries 1
#     countriesCount = c1[0].value.length;
#     $.each(c1[0].value, function (key, val) {
#         if(val.IsMemberstate) {
#         countries.push(val);
#       }
#     });
#
#     // push countries 2
#     countriesCount += c2[0].value.length;
#     $.each(c2[0].value, function (key, val) {
#       if(val.IsMemberstate) {
#         countries.push(val);
#       }
#     });
#
#     // push countries 3
#     if(c3[0].value.length > 0) {
#       countriesCount += c3[0].value.length;
#       $.each(c3[0].value, function (key, val) {
#         if(val.IsMemberstate) {
#         countries.push(val);
#       }
#       });
#     }
#   }).then(function() {
#
#     if(countries.length > 0) {
#
#       //render kendo template
#       var templateContent = $("#template-publications").html();
#       var template = kendo.template(templateContent);
#
#       // countries regions dropdown
#       $("#filter-by-region").kendoComboBox({
#         dataTextField: "text",
#         dataValueField: "value",
#         dataSource: whoRegions,
#         filter: "contains",
#         suggest: true
#     });
#
#       $("#listView-publications").html(kendo.render(template, countries));
#
#       initIsotope();
#     }
#   });
#
#
#
# };
#
# function initIsotope() {
#   setTimeout(function(){
#
#     // quick search regex
#   var qsRegex;
#
#   // init Isotope
#   var $grid = $('#listView-publications').isotope({
#     itemSelector: '.sf-publications-item',
#     originLeft: originLeft,
#     layoutMode: 'fitRows',
#     filter: function() {
#        var $this = $(this);
#         var $title = $this.find("h3.sf-publications-item__title");
#         var searchResult = qsRegex ? $title.text().match(qsRegex) : true;
#         var buttonResult = buttonFilter ? $this.is(buttonFilter) : true;
#         //console.log(this);
#         return searchResult && buttonResult;
#     }
#   });
#
#      $('#filter-by-region').on('change', function () {
#     // get filter value from option value
#     var filterValue = this.value;
#     buttonFilter = filterValue;
#     $grid.isotope();
# });
#
#   // use value of search field to filter
#   var $quicksearch = $('.quicksearch').keyup( debounce( function() {
#     qsRegex = new RegExp( $quicksearch.val(), 'gi' );
#     $grid.isotope();
#   }, 500 ) );
#
#   // debounce so filtering doesn't happen every millisecond
#   function debounce( fn, threshold ) {
#     var timeout;
#     threshold = threshold || 100;
#     return function debounced() {
#       clearTimeout( timeout );
#       var args = arguments;
#       var _this = this;
#       function delayed() {
#         fn.apply( _this, args );
#       }
#       timeout = setTimeout( delayed, threshold );
#     };
#   }
#   }, 300);
#   };
#
#
#   $.urlParam = function (name) {
#     var results = new RegExp('[\?&]' + name + '=([^&#]*)').exec(window.location.href);
#     if (results == null) {
#         return null;
#     }
#     else {
#         return results[1] || 0;
#     }
# }
#
# $(document).ready(function() {
#
#   var publicationTypeUrlParam = $.urlParam("publicationtypes");
#   var isNotDesignMode = window.location.href.toString().indexOf("Edit") == -1;
#   var isNotPreviewMode = window.location.href.toString().indexOf("Preview") == -1;
#
#   if(isNotDesignMode) {
#     $("#filter-by-region").attr("placeholder", filter_by_region[cultureIndex]);
#       $("#filter-by-keyword").attr("placeholder", filter_by_country[cultureIndex]);
#       getAllCountriesByFilter(countriesBaseUrl);
#     }
# });
# </script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/slicknav.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/auto-complete.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/match-height.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/lazy.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/modernizr-custom.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/select2.full.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/accordion-footer-list.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/main.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/main-navigation.min.js?v=14.0.7729.18857" type="text/javascript"></script><script src="/ResourcePackages/WHO/assets/dist/scripts/geo-navigation.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/image-resolution.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script type="application/ld+json">
#             {
#             "@context": "http://schema.org",
#             "@type": "CollectionPage",
#             "name": "Countries",
#             "description": "Countries overview"
#             }
#         </script> <script>
#         // Picture element HTML5 shiv
#         document.createElement("picture");
#     </script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/picturefill.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script>
#         window.define = window.__define;
#         window.require = window.__require;
#         window.__define = undefined;
#         window.__require = undefined;
#     </script> </body> </html>

# %%
country = soup.find_all("h3", attrs = {"class":"sf-publications-item__title"})
country
# Out:
# []

# %%
soup
# Out:
#  <!DOCTYPE html>
#  <html lang="en"> <head> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title>
# 	Countries | World Health Organization
# </title> <link href="/favicon.ico" rel="shortcut icon"/> <link href="/manifest.json" rel="manifest"/> <link href="/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/> <meta content="#007eb4" name="theme-color"> <link href="https://fonts.googleapis.com" rel="preconnect"> <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"> <link crossorigin="" href="https://use.fontawesome.com" rel="preconnect"> <link href="https://cdnjs.cloudflare.com" rel="dns-prefetch"/> <link href="https://kendo.cdn.telerik.com" rel="dns-prefetch"/> <link href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js" rel="prefetch"/> <link href="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js" rel="prefetch"/> <link href="https://cdn.who.int" rel="preconnect"> <link href="https://fonts.googleapis.com/css2?family=Noto+Sans:ital,wght@0,400;0,700;1,400&amp;display=swap" rel="stylesheet"/> <link href="https://use.fontawesome.com/releases/v5.15.4/css/all.css" rel="stylesheet" type="text/css"> <link href="/ResourcePackages/WHO/assets/dist/styles/grid.min.css?v=14.0.7729.18857" rel="stylesheet"/> <link href="/ResourcePackages/WHO/assets/dist/styles/origin.min.css?v=14.0.7729.18857" rel="stylesheet"/><link href="/ResourcePackages/WHO/assets/dist/styles/main.min.css?v=14.0.7729.18857" rel="stylesheet"/> <link href="/ResourcePackages/WHO/assets/dist/styles/print.min.css?v=14.0.7729.18857" media="print" rel="stylesheet"/>
# <script>
#                 var lang = document.documentElement.lang;
#                 window.dataLayer = window.dataLayer || [];
#                 window.dataLayer.push({'language': lang });
#                 window.dataLayer.push({
#   "pagetype": "collectionpage",
#   "targetaudience": "general-audience",
#   "targetcountry": "global",
#   "publishingoffice": "who-worldwide",
#   "healthtopic": "None"
# });</script> <script>
#                     (function() {
#                     function deleteCookie(cookieName,domain) {
#                         document.cookie = cookieName + '=;expires=Mon Jan 01 1900 00:00:00 ; path=/; domain=' + domain;
#                     }
#                     function loadAndTrack(canTrack) {
#                         if (!canTrack) {
#                             var domain = location.hostname.replace(/^www\./i, '.');
#                             //GA
#                             deleteCookie('_ga', domain);
#                             deleteCookie('_gat', domain);
#                             deleteCookie('_gid', domain);
#                             //Clarity
#                             deleteCookie('_clck', domain);
#                             deleteCookie('_clsk', domain);
#                             //Google Adsense
#                             deleteCookie('_gcl_au', domain);
#                         }
#                         else{
#                             //Fire GTM
#                             //Google Tag Manager
#                                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                                 })(window,document,'script','dataLayer','GTM-5QFSQRT');
#                             //End Google Tag Manager
#                         }
#                         return;
#                     }
#
#                     if (window.TrackingConsentManager) {
#                         TrackingConsentManager.addEventListener('ConsentChanged', loadAndTrack);
#                         loadAndTrack(TrackingConsentManager.canTrackCurrentUser());
#                     }
#                     else {
#                         loadAndTrack(true);
#                     }
#                     })();
#                 </script><meta content="en_US" property="og:locale"/><meta content="Countries overview | World Health Organization" property="og:title"/><meta content="Countries overview" property="og:description"/><style media="all" type="text/css">    figure.sf-publications-item__figure {margin:0 !important;width:100% !important;height:210px !important;flex-grow: 1;flex-shrink: 1;flex-direction: column;}
# .sf-publications-list .sf-publications-item__figure img {width:100%;height:auto;display: flex;flex-grow: 1;flex-shrink: 1;flex-direction: column;}
# .sf-publications-item__body {display:flex !important;flex-direction:column;flex-grow:1;flex-shrink:1;}
# .sf-publications-list .sf-publications-item__date span {display:flex !important;flex-direction:column;flex-grow:1;flex-shrink:1;height: 100%;margin-top: 1em;}
# .sf-publications-item__container {display:flex !important;flex-direction:column !important;height:100%;flex-grow:1;margin-bottom:2em !important;}
# .sf-publications-list .sf-publications-item__header {display:flex !important;flex-direction:column !important; flex-grow:1;flex-shrink:1; height:100%;}
# figure.sf-publications-item__figure { margin: 0 !important; width: 100% !important; height: auto !important; flex-grow: 1; flex-shrink: 1; flex-direction: column;}
#
# @media only screen and (max-width: 420px) {
#     .sf-publications-list .sf-publications-item__figure {display:none;}
#     .col-sm-4.col-md-3
#     {
#         width: 100% !important;
#     }
# }
# @media only screen and (min-width:420px) and (max-width: 792px) {
#     .sf-publications-list .sf-publications-item__figure {display:none;}
#     .col-sm-4.col-md-3
#     {
#         width: 50% !important;
#     }
# }
#
# .sf-publications-item__container {padding:0px;}
# .sf-publications-list .sf-publications-item__figure img {box-shadow: none;}
# figure.sf-publications-item__figure {flex-grow:0;}
# .sf-publications-list .sf-publications-item__body {padding:12px 12px 0px 12px;height: 100%;min-height: 100%;}
# .sf-publications-item__container:hover {box-shadow: 0px 2px 6px rgba(0, 0, 0, 0.15);}
# .sf-publications-list .sf-publications-item__date span {margin-top:0px;font-size:12px;color:#6a6a6a;}
# .sf-publications-list h3.sf-publications-item__title {height:4em;min-height:3em;flex-grow:1;}
# .sf-publications-list .sf-publications-item__actions {display:flex;flex-grow: 0;flex-shrink: 0;flex-direction:column;height: 100%;min-height: 1px;}
# .sf-publications-list .sf-publications-item__actions {position:relative;align-content: end;align-items: end;align-self: end;vertical-align: bottom;width: 100%;}
# .sf-publications-list .sf-publications-item__file, .sf-publications-list .sf-publications-item__url {display: flex; flex-direction: row; flex-grow:1; height:100%; width: 100%;}
# .sf-publications-list .sf-publications-item__container {padding-bottom:0;width:100%;}
# .sf-publications-list .sf-publications-item__container {
#     padding: 0px 0px;
# }
# .sf-publications-list .sf-publications-item .download-url, .sf-publications-list .sf-publications-item .page-url {
#     font-size: 12px;
# }
# @media (min-width: 1020px) {
#     .sf-publications-list .sf-publications-item__container {
#         min-height: 280px;
#     }
# }
#
# .sf-publications-list .sf-publications-item__date span {
# 	margin-top: 0px;
# 	font-size: 11px;
# 	color: #6a6a6a;
# }
#
# .filter-widget__wrapper .main-filter {
#     display: block !important;
# }</style><style media="all" type="text/css">input#filter-by-region {
#     padding: 18px 0 !important;
#     background-color: #fff !important;
#     border: 0 !important;
#     border-radius: 0 !important;
#     line-height: 1 !important;
#     text-indent: 16px !important;
#     color: #6a6a6a !important;
#     height: inherit;
# }</style><style media="all" type="text/css">.row-flex{display:flex;flex-direction:row}.row-flex .card{flex-grow:1}.row-flex .sf_colsIn{display:flex;flex-direction:column;flex-grow:1}.row-flex .card__content-group{display:flex;flex-direction:column;flex-grow:1}.row-flex .card__content{display:flex;flex-grow:1}.qa-details__content .sf-accordion__content p a{outline:0;color:var(--l2-neutralForegroundRest);border-bottom:1px solid var(--l2-neutralForegroundRest);text-decoration:none}.qa-details__content .sf-accordion__content p a:focus{outline:0;color:var(--l2-accentFillHover);background-color:var(--l2-neutralFillStealthHover);border-bottom:3px solid var(--l2-neutralFocus);text-decoration:none}.qa-details__content .sf-accordion__content p a:hover{outline:0;color:var(--l2-neutralForegroundRest);background-color:var(--l2-neutralFillStealthHover);border-bottom:3px solid var(--l2-neutralFocus);text-decoration:none}.mdc-card.mdc-card--background .card-media--item{background:0 0;background:linear-gradient(180deg,rgba(255,255,255,0) 0,rgba(0,0,0,.5) 25%,#000 100%)}.mdc-card.mdc-card--background a .item--title,.mdc-card.mdc-card--background a:active .item--title,.mdc-card.mdc-card--background a:focus .item--title,.mdc-card.mdc-card--background a:hover .item--title{text-decoration:none}.mdc-card a:visited .item--title,.mdc-card.mdc-card--background .item--title{color:#fff}.card--solid.bg-dark:hover{color:#fff;background-color:#20313b;border:2px solid #fff}.card--solid.bg-dark a{color:#fff;background-color:#20313b;border:2px solid #20313b}.card--solid.bg-dark a:hover{color:#20313b;background-color:#fff;border:2px solid #20313b}.card--solid.bg-dark:focus-within{color:#fff;background-color:#20313b;border:2px solid var(--l4-neutralFocus)}.mdc-card a .item--title,.mdc-card a:visited .item--title{color:var(--l4-neutralForegroundRest)}.mdc-card a:visited .item--title{color:var(--l4-neutralForegroundRest)!important}.-sf-integrated-app body,.sfPageContainer .RadDock .rdContent a.sfAddContentLnk,.zeContentMode .sfPageContainer .RadDock .rdContent,.zeLayoutMode .sfPageContainer .RadDock .rdContent,.zeSettingsMode .sfPageContainer .RadDock .rdContent,.zeThemesMode .sfPageContainer .RadDock .rdContent{font-family:Arial,Verdana,sans-serif!important}#navigationToScrape .content-block a,.alphabetical-nav--list .alphabetical-nav--list-item a,.alphabetical-nav--list a,.nav--list a{text-decoration:none!important}.sf-events-wrapper .vertical-list-item:focus,.sf-events-wrapper .vertical-list-item:focus-within{outline:2px solid var(--l4-neutralFocus)!important}.sf-events-wrapper .vertical-list-item a:focus-within,.sf-events-wrapper .vertical-list-item:focus{outline:0}.top-header li.active>a,.top-header li.open>a,.top-header li.selected>a,.top-header li:hover>a{background-color:var(--d-l4-accentFillHover)}
# .webinars-listing .sf-multimedia-item__container {
#     aspect-ratio: 16/9;
#     width: 100%;
#     height: auto !important;
#     min-height: 304px;
# }
#
# .webinar-episodes.vertical-list .vertical-list-item .thumb {
#     min-height: 131px;
#     aspect-ratio: 16/9;
#     height: auto;
#     width: 100%;
# }
#
# @media screen and (max-width:768px) {
#     .webinar-episodes.vertical-list .vertical-list-item .thumb {display:none;}
#
# }
#
# .webinar-episodes-details .sf-multimedia-item__container {
#     height: 390px;
#     aspect-ratio: 16/9;
#     height: auto;
# }
#
# .mdc-card--background a:visited .item--title {
#     color: #fff!important;
# }
# .hero-image--content.plx-bg--transparent.text-center {
#     position: relative;
#     width: 100%;
#     max-width: 100%;
# }
# .k-safari .plx-static .inner.responsive-background-image {
#     background-attachment: unset;
#     background-position: center;
#     background-repeat: no-repeat;
#     background-size: contain;
# }
# .plx-static.hero-image--wrapper.has-caption {
#         margin-bottom: 0;
# }
# @media (max-width: 768px) {
# .row--flex, .row-flex {flex-wrap:wrap;}
# .row--flex .sf_colsIn {margin-bottom:1rem;}
# }
# </style><style media="all" type="text/css">.sf-publications-list .sf-publications-item__figure img {
#     content-visibility: auto;
# }</style><style media="all" type="text/css">@media (min-width: 1020px) {
# .row.flex-ar {display: flex;flex-direction: row;align-content: stretch;}
# .row.flex-ar .sf_colsIn.col-sm-6.col-md-3{display:flex;flex-grow:1;;margin-bottom:2em;}
#     }
# .flex-ar img.mdc-card__media--4-3 {
#     aspect-ratio: 1/1;
# }</style><meta content="summary_large_image" name="twitter:card"/><meta content="Sitefinity 14.3.8028.0 DX" name="Generator"/><link href="https://www.who.int/countries" rel="canonical"><meta content="Countries overview" name="description"/><meta content="países" name="keywords"/></link></link></link></link></link></link></meta></head> <body class="sf-body"> <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5QFSQRT" style="display:none;visibility:hidden" width="0"></iframe></noscript><script src="/ScriptResource.axd?d=okuX3IVIBwfJlfEQK32K3l5K7YGiATb30h89J0olbNMeAyOtdYE6_Exv9Bd_ta2_XSFvjotxKLnlt9vcM6Kg3aKCXjsPLAfc02HCCEnrn0StjUGoNmpcNHr0Q7qewBsI-wQmYIVPg1mLq03jlrRY4M-hzwvjWouuBv3ehropIpydPBUR0&amp;t=ffffffff829b44f1" type="text/javascript"></script><script src="/ScriptResource.axd?d=ePnjFy9PuY6CB3GWMX-b_9dUqj_iyHKbtZiYzX__OhcBoGTfz1BCLaN4h7Fbajcqvr0jzshQTloWygrPD-ACaSqbbnMU2RjynHKyNq228hugZnvpXRMVXdY9OyDF4Ewext63iLJGrHIt24Ious-uCOclPLq5lpYk7ok9AjUyDR56hxVu0&amp;t=ffffffff829b44f1" type="text/javascript"></script><script src="/ScriptResource.axd?d=2z9h4-hKx8Yk1hygmet7pjkFguWG8Z1Fhnuod_CvCHCExwAB9TmazYiwtnNc8_PE_sQ84nrSkjqY9EALBnpl3lcKaF9OEQUFbopzQYCfhpJXDQLR-yvNY8t812iM5Aejg6fxAEzrTW8MI2owx-zl9SrMG73lcKP32vb5eFgX02xyZpHf0&amp;t=ffffffff829b44f1" type="text/javascript"></script> <div class="sf-main-site main-site main"> <header> <div class="sf-top-header top-header" id="sf-top-header"> <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container">
# <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="TopHeader_TD9F2A204012_Col00">
# </div>
# <div class="row" data-sf-element="Row"> <div class="sf_colsIn col-md-4" data-placeholder-label="Geo Navigation" data-sf-element="Geo Navigation">
# <div id="sf-geo-navigation-container">
# <nav class="sf-geo-navigation">
# <ul class="sf-primary-geo-navigation">
# <li class="active sf-no-logo">
# <a class="mobile nav-logo" href="https://www.who.int/">
# <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue.svg?sfvrsn=aaed4f35_20"/>
# </a>
# <a class="desktop" href="https://www.who.int/">Global</a>
# </li>
# <li class="has-children">
# <a href="#">Regions</a>
# <div class="sf-secondary-geo-navigation-container">
# <div class="sf-secondary-geo-navigation-wrapper">
# <div class="sf-geo-navigation-title">
# <div class="nav-header">
# <span class="nav-logo">
# <img alt="World Health Organization" class="svg" src="/images/default-source/fallback/header-logos/h-logo-blue.svg?sfvrsn=aaed4f35_20"/>
# </span>
# <span class="nav-title">WHO Regional websites</span>
# <div class="nav-back-btn"><i class="fas fa-angle-left"></i></div>
# </div>
# </div>
# <ul class="sf-secondary-geo-navigation sf-secondary-geo-navigation-region row">
# <li class="col-md-4">
# <a href="https://www.afro.who.int/">
# <img alt="Africa" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/africa.png?sfvrsn=3204f957_18"/>
# <span>Africa</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="https://www.paho.org/hq/index.php?lang=en">
# <img alt="Americas" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/americas.png?sfvrsn=9efd6df3_18"/>
# <span>Americas</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="https://www.who.int/southeastasia">
# <img alt="South-East Asia" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/south-east-asia.png?sfvrsn=68e76dc2_16"/>
# <span>South-East Asia</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="https://www.who.int/europe/">
# <img alt="Europe" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/europe.png?sfvrsn=c7d5c5a5_18"/>
# <span>Europe</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="http://www.emro.who.int/index.html">
# <img alt="Eastern Mediterranean" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/eastern-mediterranean.png?sfvrsn=71211e18_16"/>
# <span>Eastern Mediterranean</span>
# </a>
# </li>
# <li class="col-md-4">
# <a href="https://www.who.int/westernpacific/">
# <img alt="Western Pacific" class="lazy-navigation-icons" data-src="/images/default-source/fallback/maps/western-pacific.png?sfvrsn=88cbdcd5_16"/>
# <span>Western Pacific</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# </div> <div class="sf_colsIn col-md-8" data-placeholder-label="Language Selector &amp; Search" data-sf-element="Language Selector &amp; Search" role="search">
# <div class="form-inline">
# <div class="form-group sf-search-input-wrapper" role="search">
# <div class="srchaction-wrapper">
# <span class="srchaction">
# <i aria-hidden="true" class="fa fa-search fa-2x fa-loaded" id="4c82a9e8-41e4-4fb0-bd86-520c49b93e1e"></i>
# </span>
# <input aria-autocomplete="both" aria-describedby="SearchInfo-1" class="form-control" id="a5e6b2f9-6cf7-4f02-ba8d-ce433dbe7305" placeholder="Search" title="Search input" type="search" value=""/>
# </div>
# <span class="srchtoggle">
# <i aria-hidden="true" class="fa fa-search fa-2x fa-loaded"></i>
# </span>
# <span aria-hidden="true" hidden="" id="SearchInfo-1">When autocomplete results are available use up and down arrows to review and enter to select.</span>
# </div>
# <input data-sf-role="resultsUrl" type="hidden" value="/home/search-results"/>
# <input data-sf-role="indexCatalogue" type="hidden" value="genericsearchindex1"/>
# <input data-sf-role="wordsMode" type="hidden" value="AnyWord"/>
# <input data-sf-role="disableSuggestions" type="hidden" value="true"/>
# <input data-sf-role="minSuggestionLength" type="hidden" value="3"/>
# <input data-sf-role="suggestionFields" type="hidden" value="Title,Content"/>
# <input data-sf-role="language" type="hidden" value="en"/>
# <input data-sf-role="siteId" type="hidden" value="15210d59-ad60-47ff-a542-7ed76645f0c7"/>
# <input data-sf-role="suggestionsRoute" type="hidden" value="/restapi/search/suggestions"/>
# <input data-sf-role="searchTextBoxId" type="hidden" value="#a5e6b2f9-6cf7-4f02-ba8d-ce433dbe7305"/>
# <input data-sf-role="searchButtonId" type="hidden" value="#4c82a9e8-41e4-4fb0-bd86-520c49b93e1e"/>
# </div>
# <div class="dd sf-lang-selector language-selector">
# <i class="fas fa-language"></i>
# <label for="language-selector">
# Select language
# </label>
# <select id="language-selector" name="language-selector" onchange="openLink(value)">
# <option disabled="" selected="">Select language</option>
# <option class="selected" value="en">English</option>
# <option value="ar">العربية</option>
# <option value="zh">中文</option>
# <option value="fr">Français</option>
# <option value="ru">Русский</option>
# <option value="es">Español</option>
# <option value="pt">Português</option>
# </select>
# <i class="fas fa-angle-down"></i>
# </div>
# <style>
# li.slicknav_addition.sf-lang-selector{width:100%;position:relative}li.slicknav_addition.sf-lang-selector select{min-width:100%}#search-form label{visibility:hidden}.language-selector label{width:0!important;height:0;display:inline-block;overflow:hidden}
# </style>
# </div> </div> </div> </div> <div class="main-header" id="sf-main-header"> <div class="container"> <div class="row" data-sf-element="Row"> <div class="sf_colsIn col-md-12" data-placeholder-label="Logos Geo Navigation" data-sf-element="Logos">
# <div class="header-logo logos-container"> <a class="primary-logo" href="/" title="Home"> <img alt="Home" class="logo svg" src="/ResourcePackages/WHO/assets/dist/images/logos/en/h-logo-blue.svg"/> </a> </div> </div> </div> </div>
# <div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="MainHeader_TEC2026FA002_Col00">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="MainHeader_TEC2026FA002_Col01">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="MainHeader_TEC2026FA002_Col02">
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="MainHeader_TEC2026FA002_Col03">
# </div>
# </div>
# </div> <div class="navigation" id="navigationToScrape" role="navigation">
# <div class="row navWrapper" data-sf-element="Row">
# <div class="nav-container">
# <ul class="nav"></ul>
# </div>
# <ul class="nav-mobile"></ul>
# <div class="sf_colsIn col-md-12" data-placeholder-label="Menu Wrapper" data-sf-element="Menu Wrapper" id="Navigation_TD9F2A204024_Col00"><div class="navItemLayout navHomeItemLayout">
# <div class="sf_colsIn col-md-12 navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204025_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/" target="_self">Home</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204025_Col01"></div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204029_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/health-topics" target="_self">Health Topics</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204029_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_T75121FDA161_Col00"><div class="sf_colsIn horizontal" data-placeholder-label="Horizontal" data-sf-element="Horizontal" id="Navigation_TD9F2A204114_Col00">
# <div class="sf-content-block content-block">
# <div><ul><li><a data-sf-ec-immutable="" data-sf-marked="" href="/health-topics/">All topics</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#A">A</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#B">B</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#C">C</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#D">D</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#E">E</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#F">F</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#G">G</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#H">H</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#I">I</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#J">J</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#K">K</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#L">L</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#M">M</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#N">N</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#O">O</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#P">P</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#Q">Q</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#R">R</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#S">S</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#T">T</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#U">U</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#V">V</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#W">W</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#X">X</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#Y">Y</a></li><li><a data-sf-ec-immutable="" href="/health-topics/#Z">Z</a></li></ul></div>
# </div>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_T75121FDA161_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/health-topics/resources" target="_self">Resources</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/health-topics/resources/fact-sheets" target="_self">Fact sheets</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/facts-in-pictures" target="_self">Facts in pictures</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/multimedia" target="_self">Multimedia</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/publications" target="_self">Publications</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/questions-and-answers" target="_self">Questions and answers</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/resources/tools-and-toolkits" target="_self">Tools and toolkits</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_T75121FDA161_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/health-topics/popular" target="_self">Popular</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/health-topics/popular/covid-19" target="_self">COVID-19</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/dengue" target="_self">Dengue</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/herpes" target="_self">Herpes</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/hypertension" target="_self">Hypertension</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/mental-disorders" target="_self">Mental disorders</a>
# </li>
# <li class="">
# <a href="/mega-menu/health-topics/popular/top-10-causes-of-death" target="_self">Top 10 causes of death</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_T75121FDA161_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204027_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/countries" target="_self">Countries</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204027_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204039_Col00"><div class="sf_colsIn horizontal" data-placeholder-label="Horizontal" data-sf-element="Horizontal" id="Navigation_TD9F2A204043_Col00">
# <div class="sf-content-block content-block">
# <div><ul><li><a data-sf-ec-immutable="" data-sf-marked="" href="/countries/">All countries</a></li><li><a data-sf-ec-immutable="" href="/countries/#A">A</a></li><li><a data-sf-ec-immutable="" href="/countries/#B">B</a></li><li><a data-sf-ec-immutable="" href="/countries/#C">C</a></li><li><a data-sf-ec-immutable="" href="/countries/#D">D</a></li><li><a data-sf-ec-immutable="" href="/countries/#E">E</a></li><li><a data-sf-ec-immutable="" href="/countries/#F">F</a></li><li><a data-sf-ec-immutable="" href="/countries/#G">G</a></li><li><a data-sf-ec-immutable="" href="/countries/#H">H</a></li><li><a data-sf-ec-immutable="" href="/countries/#I">I</a></li><li><a data-sf-ec-immutable="" href="/countries/#J">J</a></li><li><a data-sf-ec-immutable="" href="/countries/#K ">K</a></li><li><a data-sf-ec-immutable="" href="/countries/#L ">L</a></li><li><a data-sf-ec-immutable="" href="/countries/#M ">M</a></li><li><a data-sf-ec-immutable="" href="/countries/#N ">N</a></li><li><a data-sf-ec-immutable="" href="/countries/#O ">O</a></li><li><a data-sf-ec-immutable="" href="/countries/#P ">P</a></li><li><a data-sf-ec-immutable="" href="/countries/#Q ">Q</a></li><li><a data-sf-ec-immutable="" href="/countries/#R ">R</a></li><li><a data-sf-ec-immutable="" href="/countries/#S ">S</a></li><li><a data-sf-ec-immutable="" href="/countries/#T ">T</a></li><li><a data-sf-ec-immutable="" href="/countries/#U ">U</a></li><li><a data-sf-ec-immutable="" href="/countries/#V ">V</a></li><li><a data-sf-ec-immutable="" href="/countries/#W ">W</a></li><li><a data-sf-ec-immutable="" href="/countries/#X ">X</a></li><li><a data-sf-ec-immutable="" href="/countries/#Y ">Y</a></li><li><a data-sf-ec-immutable="" href="/countries/#Z ">Z</a></li></ul></div>
# </div>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204039_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/countries/regions" target="_self">Regions</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/countries/regions/africa" target="_self">Africa</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/americas" target="_self">Americas</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/europe" target="_blank">Europe</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/eastern-mediterranean" target="_self">Eastern Mediterranean</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/south-east-asia" target="_self">South-East Asia
# </a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/regions/western-pacific" target="_blank">Western Pacific</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204039_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/countries/who-in-countries" target="_self">WHO in countries</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/countries/who-in-countries/cooperation-strategies" target="_self">Cooperation strategies</a>
# </li>
# <li class="">
# <a href="/mega-menu/countries/who-in-countries/data-by-country" target="_self">Data by country</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204039_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204028_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/news-room" target="_self">Newsroom</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204028_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204038_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/news/all-news" target="_self">All news</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/news/all-news/releases" target="_self">News releases</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/statements" target="_self">Statements</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/campaigns" target="_self">Campaigns</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/events" target="_self">Events</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/feature-stories" target="_self">Feature stories</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/speecheshub" target="_self">Speeches</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/commentaries" target="_self">Commentaries</a>
# </li>
# <li class="">
# <a href="/mega-menu/news/all-news/photo-library" target="_self">Photo library</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-md-6" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204038_Col01">
# <div class="sf-content-block content-block">
# <div><ul><li><a href="/news-room/headlines">Headlines</a></li></ul></div>
# </div>
# <div class="vertical-list" id="listView"></div>
# <script id="template" type="text/x-kendo-tmpl">
#     <div class="vertical-list-item">
#         <div class="info">
#             <a href="https://www.who.int/news/item#:ItemDefaultUrl #" aria-label="#: Title #" role="link">
#                 <p class="heading">#: Title #</p>
#             </a>
#             <div class="date">
#                 <span class="timestamp">#: FormatedDate #</span>
#                 <div class="sf-tags-list">
#                     <div class="sf-tags-list-item">#: NewsType #</div>
#                 </div>
#             </div>
#         </div>
#     </div>
# </script>
# <script>
#     window.onload = function () {
#         var remoteDataSource = new kendo.data.DataSource({
#             type: "odata-v4",
#             transport: {
#                 read: "/api/news/newsitems?sf_provider=OpenAccessDataProvider&sf_culture=en&$top=3&$orderby=PublicationDateAndTime%20desc&$select=Title,ItemDefaultUrl,FormatedDate,NewsType&$filter=publishingoffices/any(s:s eq df302c0e-1f59-4efb-b276-d154122d3760)"
#             }
#         });
#         $("#listView").kendoListView({
#             dataSource: remoteDataSource,
#             pageable: true,
#             template: kendo.template($("#template").html()),
#             dataBound: function () {
#                 this.wrapper.removeClass("k-widget");
#                 this.wrapper.removeClass("k-listview");
#             }
#         });
#     };
# </script>
# </div>
# <div class="sf_colsIn col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204038_Col02">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204040_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/emergencies" target="_self">Emergencies</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204040_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204090_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/emergencies/emergencies" target="_self">Focus on</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/afghanistan" target="_self">Afghanistan</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/cholera" target="_self">Cholera </a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/greater-horn-of-africa" target="_self">Greater Horn of Africa</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/israel-and-occupied-palestinian-territory" target="_self">Israel and occupied Palestinian territory</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/sudan" target="_self">Sudan</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/emergencies/ukraine-emergency" target="_self">Ukraine</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204090_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/emergencies/news" target="_self">Latest</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/emergencies/news/disease-outbreak-news" target="_self">Disease Outbreak News</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/news/situation-reports" target="_self">Situation reports</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/news/weekly-epidemiological-record" target="_self">Weekly Epidemiological Record</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204090_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies" target="_self">WHO in emergencies</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/surveillance" target="_self">Surveillance</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/operations" target="_self">Operations</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/research-development" target="_self">Research</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/funding" target="_self">Funding</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/partners" target="_self">Partners</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/health-emergency-appeal" target="_self">Health emergency appeal</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/international-health-regulations" target="_self">International Health Regulations</a>
# </li>
# <li class="">
# <a href="/mega-menu/emergencies/who-in-emergencies/independent-oversight-and-advisory-committee" target="_self">Independent Oversight and Advisory Committee</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204090_Col03">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_T75121FDA215_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/data" target="_self">Data</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_T75121FDA215_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_T75121FDA217_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/data/data-at-who" target="_self">Data at WHO</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/data/data-at-who/classifications" target="_self">Classifications</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/data-at-who/data-collections" target="_self">Data collections</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/data-at-who/global-health-estimates" target="_self">Global Health Estimates</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/data-at-who/mortality-database" target="_self">Mortality Database</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/data-at-who/health-sdgs" target="_self">Sustainable Development Goals</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_T75121FDA217_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/data/dashboards" target="_self">Dashboards</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/data/dashboards/covid-19-dashboard" target="_self">COVID-19</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/dashboards/health-inequality-monitor" target="_self">Health Inequality Monitor</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/dashboards/triple-billiondashboard" target="_self">Triple Billion</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_T75121FDA217_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/data/highlights" target="_self">Highlights</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/data/highlights/data-collection-tools" target="_self">Data collection tools</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/highlights/gho" target="_self">Global Health Observatory</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/highlights/insights-and-visualizations" target="_self">Insights and visualizations</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/highlights/score" target="_self">SCORE</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_T75121FDA217_Col03">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/data/reports" target="_self">Reports</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/data/reports/covid-excess-deaths" target="_self">COVID excess deaths</a>
# </li>
# <li class="">
# <a href="/mega-menu/data/reports/world-health-statistics" target="_self">World Health Statistics</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navItemLayout">
# <div class="sf_colsIn navParent" data-placeholder-label="Menu Parent Link" data-sf-element="Menu Parent Link" id="Navigation_TD9F2A204026_Col00">
# <nav role="navigation">
# <ul class="main-navigation">
# <li class=""><a href="/mega-menu/about-us" target="_self">About WHO</a></li>
# </ul>
# </nav>
# </div>
# <div class="container">
# <div class="row">
# <div class="sf_colsIn col-md-12 navDropdown" data-placeholder-label="Menu Item Dropdown" data-sf-element="Menu Item Dropdown" id="Navigation_TD9F2A204026_Col01"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 1" data-sf-element="Column 1" id="Navigation_TD9F2A204035_Col00">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/about" target="_self">About WHO</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/about/partnerships-and-collaboration" target="_self">Partnerships</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/expert-groups" target="_self">Committees and advisory groups</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/collaborating-centres" target="_self">Collaborating centres</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/teams" target="_self">Technical teams</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/structure" target="_self">Organizational structure</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/about/who-we-are" target="_self">Who we are</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 2" data-sf-element="Column 2" id="Navigation_TD9F2A204035_Col01">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/our-work" target="_self">Our work</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/our-work/activities" target="_self">Activities</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/our-work/initiatives" target="_self">Initiatives</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/our-work/global-programme-of-work" target="_self">Global Programme of Work</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/our-work/who-academy" target="_self">WHO Academy</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 3" data-sf-element="Column 3" id="Navigation_TD9F2A204035_Col02">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/who-funding" target="_self">Funding</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/who-funding/investment-case" target="_self">Investment case</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/who-funding/who-foundation" target="_self">WHO Foundation</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/accountability" target="_self">Accountability</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/accountability/audit" target="_self">Audit</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/accountability/financial-statements" target="_self">Financial statements</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/accountability/budget" target="_self">Programme budget</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/accountability/results-report" target="_self">Results Report</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="sf_colsIn col-sm-6 col-md-3" data-placeholder-label="Column 4" data-sf-element="Column 4" id="Navigation_TD9F2A204035_Col03">
# <div class="main-navigation--wrapper">
# <ul class="main-navigation navVertical">
# <li class="">
# <a href="/mega-menu/about-us/governance" target="_self">Governance</a>
# <ul class="sub-level">
# <li class="">
# <a href="/mega-menu/about-us/governance/governing-bodies-website" target="_blank">Governing bodies</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/governance/wha" target="_self">World Health Assembly</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/governance/eb" target="_self">Executive Board</a>
# </li>
# <li class="">
# <a href="/mega-menu/about-us/governance/member-states-portal" target="_self">Member States Portal</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div> </header> <section class="sf-content content" role="main">
# <div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="PageContent_TA51A0481002_Col00">
# <div>
# <ul class="sf-breadscrumb breadcrumb">
# <li><a href="/">Home</a><span>/</span></li>
# <li class="active">Countries</li>
# </ul>
# </div>
# <script type="application/ld+json">
#     {"itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.who.int","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.who.int/countries","name":"Countries"}}],"itemListOrder":"ItemListOrderAscending","@context":"http://schema.org","@type":"BreadcrumbList"}
# </script>
# </div>
# <div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-12" data-placeholder-label="Body content" data-sf-element="Column 1" id="PageContent_TA51A0481001_Col00"><div class="sf_colsIn container" data-placeholder-label="Container" data-sf-element="Container" id="PageContent_C013_Col00"><div class="row" data-sf-element="Row">
# <div class="sf_colsIn col-md-1" data-placeholder-label="Column 1" data-sf-element="Column 1" id="PageContent_C017_Col00">
# </div>
# <div class="sf_colsIn col-md-10" data-placeholder-label="Column 2" data-sf-element="Column 2" id="PageContent_C017_Col01">
# <div class="sf-content-block content-block">
# <div><h1>Countries</h1></div>
# </div>
# <div class="sf-content-block content-block">
# <div><div>All countries which are Members of the United Nations may become members of WHO by accepting its Constitution. Other countries may be admitted as members when their application has been approved by a simple majority vote of the World Health Assembly.
# ...
# <a data-sf-ec-immutable="" href="https://www.tiktok.com/@who?lang=en" target="_blank" title="Follow WHO on TikTok"><svg viewbox="0 0 448 512" xmlns="http://www.w3.org/2000/svg">
# <path d="M448,209.91a210.06,210.06,0,0,1-122.77-39.25V349.38A162.55,162.55,0,1,1,185,188.31V278.2a74.62,74.62,0,1,0,52.23,71.18V0l88,0a121.18,121.18,0,0,0,1.86,22.17h0A122.18,122.18,0,0,0,381,102.39a121.43,121.43,0,0,0,67,20.14Z" fill="white"></path></svg></a></div>
# </div>
# </div> <div class="col-md-4 copyright"> <span>
# ©
# </span>
# 2024
# <div class="sf-content-block content-block">
# <div><a href="/about/policies/terms-of-use">WHO</a></div>
# </div>
# </div> </div> </div> </div> </footer> </div> <script>
#         window.__define = window.define;
#         window.__require = window.require;
#         window.define = undefined;
#         window.require = undefined;
#     </script> <script src="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.all.min.js" type="text/javascript"></script><script src="https://kendo.cdn.telerik.com/2021.1.119/js/kendo.timezones.min.js" type="text/javascript"></script><script src="/ResourcePackages/WHO/assets/dist/scripts/responsivelylazy.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/gsap.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/ScrollTrigger.min.js" type="text/javascript"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.11.4/ScrollToPlugin.min.js" type="text/javascript"></script><script src="/ResourcePackages/WHO/assets/dist/scripts/parallax.min.js?package=WHO" type="text/javascript"></script><script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Search/Mvc/Scripts/SearchBox/Search-box.min.js?package=WHO&amp;v=LTE4MDg1ODAzMzc%3d" type="text/javascript"></script><script src="/Frontend-Assembly/Telerik.Sitefinity.Frontend.Navigation/Mvc/Scripts/LanguageSelector/language-selector.min.js?package=WHO&amp;v=MTQuMy44MDI4LjA%3d" type="text/javascript"></script><script src="/Mvc/Scripts/ContentBlock/content-block.min.js?package=WHO" type="text/javascript"></script><script id="PersonalizationTracker" type="application/json">
# 	{"IsPagePersonalizationTarget":false,"IsUrlPersonalizationTarget":false,"PageId":"9c9cb2b7-3f12-46ad-aa7e-4bc00ed9e527"}
# </script><script src="/WebResource.axd?d=Oiw5o8i74rDb2VpVaCaMStPoJ1dBeSniQ1UcN-tajp7S6UQI4QFVCojlg1ewuf339ZIyq0NtnQlSiEw1RQXcWIVwl_-LxzVLlNCkT-5fM3qvVhZCKMRq6X6cWc42Aw4Db6sa87yi7j5Hio4wozQZMklgyIbXX4yGQn_Sh0nCPeRw8nypcGpUIdT0MqtRIOGgRLfw327mU3tc3-bA3UOOd_v176Q1&amp;t=638309030020000000" type="text/javascript">
# </script><input data-sf-role="en" type="hidden" value="https://www.who.int/countries"/><input data-sf-role="ar" type="hidden" value="https://www.who.int/ar/countries"/><input data-sf-role="zh" type="hidden" value="https://www.who.int/zh/countries"/><input data-sf-role="fr" type="hidden" value="https://www.who.int/fr/countries"/><input data-sf-role="ru" type="hidden" value="https://www.who.int/ru/countries"/><input data-sf-role="es" type="hidden" value="https://www.who.int/es/countries"/><input data-sf-role="pt" type="hidden" value="https://www.who.int/pt/countries"/><script src="https://npmcdn.com/isotope-layout@3.0.6/dist/isotope.pkgd.js" type="text/javascript"></script><script type="text/javascript">
# //Localisation ISO code for Kendo Culture
# var date_localisation_format = [
#     "en-GB",
#     "ar",
#     "es-ES",
#     "fr-FR",
#     "ru-RU",
#     "zh"
# ];
#
# var textPosition = "k-ltr";
# var numberPosition = "";
# // used in isotope - set to false for arabic language
# var originLeft = true;
#
# // returns the value of the lang attribute - e.g. "en", "fr"
# var htmlLang = $("html").attr("lang");
#
# // optimized with if(htmlLang == "ar") { ... }
# //var cultureIndex = cultureIndexes[htmlLang];
#
# // defines the index of the language - 0 is EN and fallback
# var cultureIndex = 0;
#
# if(htmlLang == "ar")
# {
#     cultureIndex = 1;
#     textPosition = "k-rtl";
#     numberPosition = "number-ltr";
#     originLeft = false;
# }
# if(htmlLang == "es")
# {
#     cultureIndex = 2;
# }
# if(htmlLang == "fr")
# {
#     cultureIndex = 3;
# }
# if(htmlLang == "ru")
# {
#     cultureIndex = 4;
# }
# if(htmlLang == "zh")
# {
#     cultureIndex = 5;
# }
# if(htmlLang == "pt")
# {
#     cultureIndex = 6;
# }
#
# // filter by keyword placeholder label
# var filter_by_region = [
#     "Filter by region",
#     "تصفية حسب المنطقة",
#     "Filtrar por región de la OMS",
#     "Filtrer par région de l’OMS",
#     "Фильтр по регионам ВОЗ",
#     "按区域筛选",
#     "Filtrar por região"
# ];
#
# // filter by keyword placeholder label
# var filter_by_country = [
#     "Type to filter on a country",
#     "اكتب للتصفية علي بلد",
#     "Tipo para filtrar en un país",
#     "Type à filtrer sur un pays",
#     "Фильтр по странам",
#     "按国家筛选",
#     "Digite para filtrar por país"
# ];
#
# // link to the country overview page label
# var country_overview_page_link = [
#     "Visit the country overview",
#     "زيارة النظرة العامة القطرية",
#     "Visita la descripción del país",
#     "Consulter le survol du pays",
#     "Посетить обзор стран",
#     "访问国家概况",
#     "Visite a visão geral do país"
# ];
#
# var african_region = [
#     "African Region",
#     "المنطقة الأفريقية",
#     "Región Africana",
#     "Région africaine",
#     "Африканский регион",
#     "非洲地区",
#     "Região Africana"
# ];
#
# var eastern_mediterranean_region = [
#     "Eastern Mediterranean Region",
#     "منطقة شرق البحر الأبيض المتوسط",
#     "Región del Mediterráneo Oriental",
#     "Région de la Méditerranée orientale",
#     "Регион Восточного Средиземноморья",
#     "东地中海区域",
#     "Região do Mediterrâneo Oriental"
# ];
#
# var european_region = [
#     "European Region",
#     "المنطقة الأوروبية",
#     "Región Europea",
#     "Région européenne",
#     "Европейский регион",
#     "欧洲地区",
#     "Região Europeia"
# ];
#
# var region_of_the_americas = [
#     "Region of the Americas",
#     "منطقة الأمريكتين",
#     "Región de las Américas",
#     "Région des Amériques",
#     "Регион Америки",
#     "美洲地区",
#     "Região das Américas"
# ];
#
# var south_east_asia_region = [
#     "South-East Asia Region",
#     "منطقة جنوب شرق آسيا",
#     "Región de Asia Sudoriental",
#     "Région Asie du Sud-Est",
#     "Регион юго-восточной Азии",
#     "东南亚区域",
#     "Sudeste Asiático"
# ];
#
# var western_pacific_region = [
#     "Western Pacific Region",
#     "منطقة غرب المحيط الهادئ",
#     "Región del Pacífico Occidental",
#     "Région du Pacifique occidental",
#     "Западно-Тихоокеанский регион",
#     "西太平洋地区",
#     "Região do Pacífico Ocidental"
# ];
#
# var who_worldwide = [
#     "WHO Worldwide",
#     "منظمة الصحة العالمية في جميع أنحاء العالم",
#     "OMS en todo el mundo",
#     "OMS dans le monde",
#     "ВОЗ во всем мире",
#     "世卫组织全球",
#     "OMS em todo o mundo"
# ];
# </script><script type="text/javascript">
# var hostName = window.location.host;
# var countriesCount = 0;
# var countries = [];
# var countriesPageUrl = "/countries/";
# var position = 1;
# var buttonFilters = {};
# var buttonFilter;
# var webitCulture = "/";
# var trailingSlash = "/";
# //used to filter all countries which are member states only
# var memberStateClassificationId = "efb425be-c0b9-42d1-84b4-c3814fb5c18d";
#
# var whoRegions = [
#   { text: african_region[cultureIndex], value: ".african-region" },
#   { text: eastern_mediterranean_region[cultureIndex], value: ".eastern-mediterranean-region" },
#   { text: european_region[cultureIndex], value: ".european-region" },
#   { text: region_of_the_americas[cultureIndex], value: ".region-of-the-americas" },
#   { text: south_east_asia_region[cultureIndex], value: ".south-east-asia-region" },
#   { text: western_pacific_region[cultureIndex], value: ".western-pacific-region" },
#   { text: who_worldwide[cultureIndex], value: ".element-item" }
# ];
#
# var flagLibraryUrl = "https://" + hostName + "/images/default-source/countries-overview/flags/";
# var thumbnailProfile = ".tmb-768v";
#
# // service urls - no filtering
# var countriesBaseUrl = "https://" + hostName + "/api/multimedias/countries?$select=Title,whostatus,IsMemberstate,OfficialName,WhoCode,Code&$expand=WHORegion,Flag($select=Title,UrlName,Url,ThumbnailUrl,Extension)&$filter=whostatus/any(x:x%20eq%20" + memberStateClassificationId + ")&$orderBy=Title%20asc&sf_culture=" + htmlLang;
#
# function getAllCountriesByFilter(countriesBaseUrl) {
#   countries = [];
#   countriesCount = 0;
#
#   var countries1 = countriesBaseUrl + "&$top=100&$skip=0&$count=true";
#   var countries2 = countriesBaseUrl + "&$top=100&$skip=100&$count=true";
#   var countries3 = countriesBaseUrl + "&$top=100&$skip=200&$count=true";
#
#   $.when($.ajax(countries1), $.ajax(countries2), $.ajax(countries3))
#   .then(function(c1, c2, c3) {
#
#     // push countries 1
#     countriesCount = c1[0].value.length;
#     $.each(c1[0].value, function (key, val) {
#         if(val.IsMemberstate) {
#         countries.push(val);
#       }
#     });
#
#     // push countries 2
#     countriesCount += c2[0].value.length;
#     $.each(c2[0].value, function (key, val) {
#       if(val.IsMemberstate) {
#         countries.push(val);
#       }
#     });
#
#     // push countries 3
#     if(c3[0].value.length > 0) {
#       countriesCount += c3[0].value.length;
#       $.each(c3[0].value, function (key, val) {
#         if(val.IsMemberstate) {
#         countries.push(val);
#       }
#       });
#     }
#   }).then(function() {
#
#     if(countries.length > 0) {
#
#       //render kendo template
#       var templateContent = $("#template-publications").html();
#       var template = kendo.template(templateContent);
#
#       // countries regions dropdown
#       $("#filter-by-region").kendoComboBox({
#         dataTextField: "text",
#         dataValueField: "value",
#         dataSource: whoRegions,
#         filter: "contains",
#         suggest: true
#     });
#
#       $("#listView-publications").html(kendo.render(template, countries));
#
#       initIsotope();
#     }
#   });
#
#
#
# };
#
# function initIsotope() {
#   setTimeout(function(){
#
#     // quick search regex
#   var qsRegex;
#
#   // init Isotope
#   var $grid = $('#listView-publications').isotope({
#     itemSelector: '.sf-publications-item',
#     originLeft: originLeft,
#     layoutMode: 'fitRows',
#     filter: function() {
#        var $this = $(this);
#         var $title = $this.find("h3.sf-publications-item__title");
#         var searchResult = qsRegex ? $title.text().match(qsRegex) : true;
#         var buttonResult = buttonFilter ? $this.is(buttonFilter) : true;
#         //console.log(this);
#         return searchResult && buttonResult;
#     }
#   });
#
#      $('#filter-by-region').on('change', function () {
#     // get filter value from option value
#     var filterValue = this.value;
#     buttonFilter = filterValue;
#     $grid.isotope();
# });
#
#   // use value of search field to filter
#   var $quicksearch = $('.quicksearch').keyup( debounce( function() {
#     qsRegex = new RegExp( $quicksearch.val(), 'gi' );
#     $grid.isotope();
#   }, 500 ) );
#
#   // debounce so filtering doesn't happen every millisecond
#   function debounce( fn, threshold ) {
#     var timeout;
#     threshold = threshold || 100;
#     return function debounced() {
#       clearTimeout( timeout );
#       var args = arguments;
#       var _this = this;
#       function delayed() {
#         fn.apply( _this, args );
#       }
#       timeout = setTimeout( delayed, threshold );
#     };
#   }
#   }, 300);
#   };
#
#
#   $.urlParam = function (name) {
#     var results = new RegExp('[\?&]' + name + '=([^&#]*)').exec(window.location.href);
#     if (results == null) {
#         return null;
#     }
#     else {
#         return results[1] || 0;
#     }
# }
#
# $(document).ready(function() {
#
#   var publicationTypeUrlParam = $.urlParam("publicationtypes");
#   var isNotDesignMode = window.location.href.toString().indexOf("Edit") == -1;
#   var isNotPreviewMode = window.location.href.toString().indexOf("Preview") == -1;
#
#   if(isNotDesignMode) {
#     $("#filter-by-region").attr("placeholder", filter_by_region[cultureIndex]);
#       $("#filter-by-keyword").attr("placeholder", filter_by_country[cultureIndex]);
#       getAllCountriesByFilter(countriesBaseUrl);
#     }
# });
# </script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/slicknav.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/auto-complete.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/match-height.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/lazy.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/modernizr-custom.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/select2.full.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/accordion-footer-list.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/main.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/main-navigation.min.js?v=14.0.7729.18857" type="text/javascript"></script><script src="/ResourcePackages/WHO/assets/dist/scripts/geo-navigation.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script src="/ResourcePackages/WHO/assets/dist/scripts/image-resolution.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script type="application/ld+json">
#             {
#             "@context": "http://schema.org",
#             "@type": "CollectionPage",
#             "name": "Countries",
#             "description": "Countries overview"
#             }
#         </script> <script>
#         // Picture element HTML5 shiv
#         document.createElement("picture");
#     </script> <script src="/ResourcePackages/WHO/assets/dist/scripts/lib/picturefill.min.js?v=14.0.7729.18857" type="text/javascript"></script> <script>
#         window.define = window.__define;
#         window.require = window.__require;
#         window.__define = undefined;
#         window.__require = undefined;
#     </script> </body> </html>

# %%
import pandas as pd

# %% [markdown]
# ## Transfering the files to SQL

# %%
# from sqlalchemy import create_engine 
# engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
#                        .format(user="root",
#                                pw="ALpc220918",
#                                db="vaccines"))
# covarage_df = pd.read_excel("coverage-data.xlsx")
# cases_df = pd.read_excel("reported-cases-data.xlsx")
# vaccine_df = pd.read_excel("vaccine-introduction-data.xlsx")
# covarage_df.to_sql('covarage', con = engine, if_exists = 'append')
# cases_df.to_sql('cases', con = engine, if_exists = 'append')
# vaccine_df.to_sql('vaccine', con = engine, if_exists = 'append')
# engine.dispose()

# %%
vaccine_disease = pd.read_json("/Users/arturcabral/Documents/Ironhack/Quests/Final_Project/MySQL_files/final_data_ML.json")
vaccine_disease
# Out:
#      DISEASE          DISEASE_DESCRIPTION WHO_zone  YEAR  Total_Cases  \
# 0        CRS  Congenital rubella syndrome      AFR  2004            4
# 1        CRS  Congenital rubella syndrome      AFR  2005            3
# 2        CRS  Congenital rubella syndrome      AFR  2006            8
# 3        CRS  Congenital rubella syndrome      AFR  2007            1
# 4        CRS  Congenital rubella syndrome      AFR  2009           47
# ...      ...                          ...      ...   ...          ...
# 2059  YFEVER                 Yellow fever      AMR  2018         1326
# 2060  YFEVER                 Yellow fever      AMR  2019           99
# 2061  YFEVER                 Yellow fever      AMR  2020           27
# 2062  YFEVER                 Yellow fever      AMR  2021           25
# 2063  YFEVER                 Yellow fever      AMR  2022           14
#
#                        ANTIGEN_DESCRIPTION ANTIGEN   Target    Doses
# 0     Rubella-containing vaccine, 1st dose    RCV1    20397    18485
# 1     Rubella-containing vaccine, 1st dose    RCV1    20239    18080
# 2     Rubella-containing vaccine, 1st dose    RCV1    19041    17521
# 3     Rubella-containing vaccine, 1st dose    RCV1    18258    16661
# 4     Rubella-containing vaccine, 1st dose    RCV1    16664    15587
# ...                                    ...     ...      ...      ...
# 2059                  Yellow fever vaccine     YFV  5541147  3648105
# 2060                  Yellow fever vaccine     YFV  5585104  3867556
# 2061                  Yellow fever vaccine     YFV  5584967  3613520
# 2062                  Yellow fever vaccine     YFV  5491788  3559895
# 2063                  Yellow fever vaccine     YFV  4784763  3055910
#
# [2064 rows x 9 columns]
